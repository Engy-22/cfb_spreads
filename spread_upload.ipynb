# %%
import pandas as pd
import numpy as np

# %%
spread_df = pd.read_pickle('pkl_data/spread_df.pkl')

# %%
spread_df
# Out:
#                  home_team  h_pt_spread              away_team  a_pt_spread  \
# 0                  houston    -6.915946     southern-methodist     6.915946
# 1                 colorado    -3.460836    southern-california     3.460836
# 2        northern-illinois     7.338914                  akron    -7.338914
# 3            south-alabama   -21.860485      appalachian-state    21.860485
# 4                 stanford    -5.452674                arizona     5.452674
# 5                     ucla     1.886870          arizona-state    -1.886870
# 6                  alabama    18.355972               arkansas   -18.355972
# 7          louisiana-state    13.012348                 auburn   -13.012348
# 8                  clemson    -0.047050         boston-college     0.047050
# 9                 nebraska    -8.546538                indiana     8.546538
# 10        western-michigan     5.783515    bowling-green-state    -5.783515
# ...
